# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("ford.csv")

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17966 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17966 non-null  object
#  1   year          17966 non-null  int64
#  2   price         17966 non-null  int64
#  3   transmission  17966 non-null  object
#  4   mileage       17966 non-null  int64
#  5   fuelType      17966 non-null  object
#  6   tax           17966 non-null  int64
#  7   mpg           17966 non-null  float64
#  8   engineSize    17966 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(154)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
def plotting(var,num):
    plt.subplot(2,2,num) #matplot
    sns.histplot(df[var],kde='True')
    
plotting('year',1)
plotting('price',2)
plotting('mileage',3)
plotting('tax',4)

plt.tight_layout()

# %%
price_mean = df.loc[df['price'] != 0, 'price'].mean()
# Replace 0 values with the mean
df['price'] = df['price'].replace(0,price_mean)

# %%
corr_matrix = df.corr(numeric_only=True)   # compute correlations
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
sns.boxplot(data=df, x='fuelType', y='price')
# Out:
# <Axes: xlabel='fuelType', ylabel='price'>

# %%
sns.boxplot(data=df, y='tax', x='price')
# Out:
# <Axes: xlabel='price', ylabel='tax'>

# %%
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import LabelEncoder

X = df[['model','year','transmission','fuelType','engineSize']].apply(LabelEncoder().fit_transform)
y = df['price']   # continuous

f_values, p_values = f_classif(X, y)
for col, f, p in zip(X.columns, f_values, p_values):
    decision = "Keep Feature" if p < 0.05 else "Remove Feature"
    print(f"{col}: F={f:.2f}, p={p:.4f}, {decision}")
# Out:
# model: F=2.03, p=0.0000, Keep Feature
# year: F=12.32, p=0.0000, Keep Feature
# transmission: F=1.42, p=0.0000, Keep Feature
# fuelType: F=1.46, p=0.0000, Keep Feature
# engineSize: F=2.62, p=0.0000, Keep Feature

# %% [markdown]
# # Data cleaning and preprocessing

# %%
# we can perform one hot encoding, for all columns at the same time
df_encode=pd.get_dummies(df,columns=['model','transmission','fuelType'],drop_first=True)

# %%
df_encode=df_encode.astype(int)

# %%
df_encode.head()
# Out:
#    year  price  mileage  tax  mpg  engineSize  model_ C-MAX  model_ EcoSport  \
# 0  2017  12000    15944  150   57           1             0                0
# 1  2018  14000     9083  150   57           1             0                0
# 2  2017  13000    12456  150   57           1             0                0
# 3  2019  17500    10460  145   40           1             0                0
# 4  2019  16500     1482  145   48           1             0                0
#
#    model_ Edge  model_ Escort  ...  model_ Tourneo Connect  \
# 0            0              0  ...                       0
# 1            0              0  ...                       0
# 2            0              0  ...                       0
# 3            0              0  ...                       0
# 4            0              0  ...                       0
#
#    model_ Tourneo Custom  model_ Transit Tourneo  model_Focus  \
# 0                      0                       0            0
# ...

# %%
# Label encoding 
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
from sklearn.preprocessing import LabelEncoder


# Columns to encode
categorical_cols = ['model', 'transmission', 'fuelType']

# Apply Label Encoding
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
print(df.head())
# Out:
#    model  year  price  transmission  mileage  fuelType  tax   mpg  engineSize
# 0      5  2017  12000             0    15944         4  150  57.7         1.0
# 1      6  2018  14000             1     9083         4  150  57.7         1.0
# 2      6  2017  13000             1    12456         4  150  57.7         1.0
# 3      5  2019  17500             1    10460         4  145  40.3         1.5
# 4      5  2019  16500             0     1482         4  145  48.7         1.0

# %%
from sklearn.preprocessing import StandardScaler
columns=['model','mileage','year','fuelType','tax','mpg','engineSize']
scaler=StandardScaler()
df[columns]=scaler.fit_transform(df[columns]) #for label encoded data.

# %%
df.head()
# Out:
#       model      year  price  transmission   mileage  fuelType       tax  \
# 0 -0.460281  0.067059  12000             0 -0.382994  0.688206  0.591380
# 1 -0.210828  0.554393  14000             1 -0.736317  0.688206  0.591380
# 2 -0.210828  0.067059  13000             1 -0.562616  0.688206  0.591380
# 3 -0.460281  1.041726  17500             1 -0.665405  0.688206  0.510777
# 4 -0.460281  1.041726  16500             0 -1.127749  0.688206  0.510777
#
#         mpg  engineSize
# 0 -0.020597   -0.810561
# 1 -0.020597   -0.810561
# 2 -0.020597   -0.810561
# 3 -1.737858    0.345325
# 4 -0.908836   -0.810561

# %%
from sklearn.preprocessing import StandardScaler
columns=['mileage','year','tax','mpg']
scaler=StandardScaler()
df_encode[columns]=scaler.fit_transform(df_encode[columns]) #for one hot encoded data

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %% [markdown]
# # Model

# %%
#label encoded data first.

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('price',axis=1)

# %%
y=df['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (11934, 8) (5878, 8)
# (11934,) (5878,)

# %%
from sklearn.linear_model import LinearRegression

# %%
# create a model instance
model = LinearRegression()

# fit the model on training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# make predictions on test data
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
n=X_test.shape[0]
p=X_test.shape[1]
adjusted_r2=1-((1-r2)*(n-1)/(n-p-1))
adjusted_r2
# Out:
# 0.7163583083198339

# %%
from sklearn.model_selection import train_test_split

# %%
x=df_encode.drop('price',axis=1)

# %%
Y=df_encode['price']

# %%
x_train,x_test,Y_train,Y_test=train_test_split(x,Y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
# create a model instance
model = LinearRegression()

# fit the model on training data
model.fit(x_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred= model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2=r2_score(Y_test,Y_pred)
n=x_test.shape[0]
p=x_test.shape[1]
adjusted_r2=1-((1-r2)*(n-1)/(n-p-1))
adjusted_r2
# Out:
# 0.833120933694643
